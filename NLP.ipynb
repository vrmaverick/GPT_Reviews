# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # NLP Funtamentals and project
#
# NLP has the goal of deriving information out of natural language(could be sequences text or speech)
#
# Another common term for NLP is sequence to sequence problems

# %%
# Reusing the basic functions already coded earlier
# !wget https://raw.githubusercontent.com/vrmaverick/GPT_Reviews/main/helper_functions.py
# from helper_functions import unzip_data,create_tensorboard_callback,plot_loss_curves,compare_historys
# Out:
# --2024-07-06 18:14:17--  https://raw.githubusercontent.com/vrmaverick/GPT_Reviews/main/helper_functions.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10246 (10K) [text/plain]
# Saving to: ‘helper_functions.py’
#
# helper_functions.py 100%[===================>]  10.01K  --.-KB/s    in 0s
#
# 2024-07-06 18:14:17 (84.8 MB/s) - ‘helper_functions.py’ saved [10246/10246]

# %%
from helper_functions import unzip_data,create_tensorboard_callback,plot_loss_curves,compare_historys

# %% [markdown]
# # Dataset used is from kaggle :
# https://www.kaggle.com/datasets/ashishkumarak/chatgpt-reviews-daily-updated?resource=download
#
# This Dataset contains the Reviews of GPT users The Dataset has revies and sentiments that can be analyzed periodically as the new relases are initiated
#
# # Visualizize the Text Dataset refer
# https://realpython.com/read-write-files-python/

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/datasets/chatgpt_reviews.csv')
df.head()
# Out:
#                                reviewId        userName             content  \
# 0  6bcb81f3-659e-4861-b418-8eb296918e88      Pari singh             awesome
# 1  d7c02f38-8f15-4366-a3be-e68a4bd6e47e   Saad Bin Amir            good yar
# 2  46ad05f5-f4a1-4f2b-b617-652205c786dc  basudev pandey           excellent
# 3  2974d6db-e149-4c78-8497-81e63998712d  Miss Jussantos  its a very good ap
# 4  367c9776-5ac2-4ac4-98dc-98eb3a43d254         naim gg              good 👍
#
#    score  thumbsUpCount reviewCreatedVersion                   at  appVersion
# 0      5              0           1.2024.170  2024-07-02 20:56:06  1.2024.170
# 1      5              0           1.2024.170  2024-07-02 20:50:17  1.2024.170
# 2      5              0           1.2024.170  2024-07-02 20:48:07  1.2024.170
# 3      5              0           1.2024.170  2024-07-02 20:45:47  1.2024.170
# 4      5              0           1.2024.170  2024-07-02 20:44:08  1.2024.170

# %%
df.isna().sum()
# Out:
# reviewId                    0
# userName                    1
# content                     5
# score                       0
# thumbsUpCount               0
# reviewCreatedVersion    12378
# at                          0
# appVersion              12378
# dtype: int64

# %%
# Our main columns are Content and score given so we will drop the username review created version ,at,app,version
df.drop(['userName','thumbsUpCount','reviewCreatedVersion','at','appVersion'],axis = 1,inplace=True)
df.head()
# Out:
#                                reviewId             content  score
# 0  6bcb81f3-659e-4861-b418-8eb296918e88             awesome      5
# 1  d7c02f38-8f15-4366-a3be-e68a4bd6e47e            good yar      5
# 2  46ad05f5-f4a1-4f2b-b617-652205c786dc           excellent      5
# 3  2974d6db-e149-4c78-8497-81e63998712d  its a very good ap      5
# 4  367c9776-5ac2-4ac4-98dc-98eb3a43d254              good 👍      5

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 153147 entries, 0 to 153151
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   reviewId  153147 non-null  object
#  1   content   153147 non-null  object
#  2   score     153147 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 4.7+ MB

# %%
df.describe()
# Out:
#                score
# count  153147.000000
# mean        4.493114
# std         1.095255
# min         1.000000
# 25%         5.000000
# 50%         5.000000
# 75%         5.000000
# max         5.000000

# %%
df.drop('reviewId',axis=1,inplace=True)

# %%
df.isna().sum()
X = df['content']
Y = df['score']
# There are various Diffrent languages used by people giving the revies which causes dataquality to degrade this is the biggest chalenge in nlp
# so first we must try to translate in english

# %%
# !pip install googletrans
df.isna().sum()
# Out:
# content    0
# score      0
# dtype: int64

# %%
# !pip install deep-translator
from deep_translator import GoogleTranslator

df['translated_content'] = df['content'].apply(lambda x: GoogleTranslator(source='auto', target='en').translate(x))
df
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 1.9 MB/s eta 0:00:00
# ...

# %%
df.to_csv('/content/drive/MyDrive/datasets/newGPT.csv')

# %%
from sklearn.model_selection import train_test_split
# from googletrans import Translator
# translator = Translator()
# df['translated_content'] = df['content'].apply(lambda x: translator.translate(x, dest='en').text) # Call translate on the instance
# df
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.3,random_state=98)

# %%
X_train
